# %% [markdown]
# ## NII 파일로 변환

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install dicom2nifti
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 76.1 MB/s eta 0:00:00
# ...

# %%
import dicom2nifti
import os
#한 폴더(예를 들어 M_MCI_MPRSGE)로 하면 잘 안되는 것 같아서 그냥 dcm 파일들 뜨는 바로 직전 폴더로 경로 설정해서 각각 변환시켜주었습니당~!
dicom_directory = "/content/drive/MyDrive/2023 의학영상처리/MRI/AD/F/168_S_6735"
output_directory = '/content/drive/MyDrive/2023 의학영상처리/MRI/AD/F_nii/013_S_6768'
os.makedirs(output_directory, exist_ok=True)

dicom2nifti.convert_directory(dicom_directory, output_directory)

print(len(os.listdir(dicom_directory)))
os.listdir(dicom_directory)
# Out:
# 176
# ['ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170351377_102_S842950_I1189178.dcm',
#  'ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170329576_155_S842950_I1189178.dcm',
#  'ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170319408_34_S842950_I1189178.dcm',
#  'ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170333093_81_S842950_I1189178.dcm',
#  'ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170314202_91_S842950_I1189178.dcm',
#  'ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170332539_14_S842950_I1189178.dcm',
#  'ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170314846_38_S842950_I1189178.dcm',
#  'ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170336516_142_S842950_I1189178.dcm',
#  'ADNI_013_S_6768_MR_Accelerated_Sagittal_MPRAGE__br_raw_20190719170347533_63_S842950_I1189178.dcm',
# ...

# %% [markdown]
# ## NII 파일 크기 보기

# %%
pip install nibabel

# %%
import nibabel as nib
nii = nib.load('/content/drive/MyDrive/2023 의학영상처리/MRI/AD/F_nii/003_S_6833/2_accelerated_sagittal_mprage.nii.gz').get_fdata()
print(nii.shape)
# Out:
# (208, 240, 256)
